# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from itertools import chain

sns.set()

# %%
df_final = pd.read_csv("csvs/final.csv")
df_final.rename({"Unnamed: 0":"id"}, axis=1, inplace=True)
df_final["pop"] = "1000"
df_final.head()
# Out:
#    id  tasks_completed  no_unreachable_locs   pop
# 0   0              100                  915  1000
# 1   1               88                  861  1000
# 2   2               97                  909  1000
# 3   3               84                  875  1000
# 4   4              105                  933  1000

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(data=df_final, x="tasks_completed", y="no_unreachable_locs")
# Out:
# <AxesSubplot:xlabel='tasks_completed', ylabel='no_unreachable_locs'>

# %%
df_final[df_final["no_unreachable_locs"]<650]
# Out:
#     id  tasks_completed  no_unreachable_locs   pop
# 24  24               30                  591  1000
# 25  25               44                  643  1000
# 26  26               48                  643  1000
# 27  27               43                  640  1000
# 58  58               28                  591  1000
# 59  59               34                  591  1000
# 60  60               46                  644  1000
# 61  61               38                  644  1000
# 62  62               49                  640  1000

# %%
df_0 = pd.read_csv("csvs/0.csv")
df_0.rename({"Unnamed: 0":"id"}, axis=1, inplace=True)
df_0["pop"] = "0"
df_0.head()
# Out:
#    id  tasks_completed  no_unreachable_locs pop
# 0   0               30                  884   0
# 1   1               35                  868   0
# 2   2               38                  898   0
# 3   3               39                  899   0
# 4   4               41                  915   0

# %%
df_500 = pd.read_csv("csvs/500.csv")
df_500.rename({"Unnamed: 0":"id"}, axis=1, inplace=True)
df_500["pop"] = "500"
df_500.head()
# Out:
#    id  tasks_completed  no_unreachable_locs  pop
# 0   0               40                  858  500
# 1   1               39                  858  500
# 2   2               36                  858  500
# 3   3               42                  858  500
# 4   4               47                  920  500

# %%
df_all = pd.concat([df_final, df_500, df_0], ignore_index=True)
df_all.head()
# Out:
#    id  tasks_completed  no_unreachable_locs   pop
# 0   0               32                  758  1000
# 1   1               30                  758  1000
# 2   2               42                  864  1000
# 3   3               43                  898  1000
# 4   4               32                  789  1000

# %%
fig, axs = plt.subplots(2,2, figsize=(15, 15))

for y in range(len(axs)):
    for x in range(len(axs[0])):
        axs[y][x].set_xlabel("No of Tasks Completed")
        axs[y][x].set_ylabel("No of Unreachable Locs")

axs[0][0].set_title("All Generations")
axs[0][1].set_title("Generation 0")
axs[1][0].set_title("Generation 500")
axs[1][1].set_title("Generation 1000 (Final)")
    
sns.scatterplot(data=df_all, x="tasks_completed", y="no_unreachable_locs", hue="pop", ax=axs[0][0])
sns.scatterplot(data=df_0, x="tasks_completed", y="no_unreachable_locs", ax=axs[0][1], 
                color="green")
sns.scatterplot(data=df_500, x="tasks_completed", y="no_unreachable_locs", ax=axs[1][0], 
                color="darkorange")
sns.scatterplot(data=df_final, x="tasks_completed", y="no_unreachable_locs", ax=axs[1][1])

fig.savefig("unreachable_locs_tasks_completed.png")

# %%
df_final[df_final["no_unreachable_locs"]<500]
# Out:
#       id  tasks_completed  no_unreachable_locs   pop
# 20    20               12                  446  1000
# 23    23               15                  427  1000
# 24    24               14                  427  1000
# 26    26               17                  420  1000
# 27    27               12                  420  1000
# 64    64               11                  489  1000
# 65    65               17                  446  1000
# 66    66               15                  446  1000
# 83    83               13                  427  1000
# 84    84               12                  427  1000
# 85    85               12                  427  1000
# 86    86               10                  427  1000
# 87    87               12                  427  1000
# 88    88               12                  427  1000
# 89    89               12                  427  1000
# 94    94               11                  420  1000
# 95    95               10                  420  1000
# ...

# %% [markdown]
# 26 looks good

# %%
df_final[df_final["no_unreachable_locs"]>900]
# Out:
#       id  tasks_completed  no_unreachable_locs   pop
# 5      5               49                  934  1000
# 6      6               46                  926  1000
# 7      7               45                  926  1000
# 8      8               46                  926  1000
# 19    19               47                  909  1000
# 34    34               41                  902  1000
# 39    39               50                  934  1000
# 40    40               51                  933  1000
# 61    61               50                  922  1000
# 62    62               48                  917  1000
# 63    63               45                  909  1000
# 102  102               48                  934  1000
# 103  103               52                  934  1000
# 121  121               44                  929  1000
# 126  126               48                  920  1000
# 132  132               44                  902  1000
# 133  133               44                  911  1000
# ...
